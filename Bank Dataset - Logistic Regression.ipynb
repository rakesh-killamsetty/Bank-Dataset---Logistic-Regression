# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("/content/BanK.csv")
data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
data.shape
# Out:
# (10000, 14)

# %%
data.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %%
data.groupby('NumOfProducts').count()
# Out:
#                RowNumber  CustomerId  Surname  CreditScore  Geography  Gender  \
# NumOfProducts
# 1                   5084        5084     5084         5084       5084    5084
# 2                   4590        4590     4590         4590       4590    4590
# 3                    266         266      266          266        266     266
# 4                     60          60       60           60         60      60
#
#                 Age  Tenure  Balance  HasCrCard  IsActiveMember  \
# NumOfProducts
# 1              5084    5084     5084       5084            5084
# 2              4590    4590     4590       4590            4590
# 3               266     266      266        266             266
# 4                60      60       60         60              60
#
#                EstimatedSalary  Exited
# NumOfProducts
# 1                         5084    5084
# 2                         4590    4590
# 3                          266     266
# 4                           60      60

# %%
data.groupby(['Exited','Geography']).count()
# Out:
#                   RowNumber  CustomerId  Surname  CreditScore  Gender   Age  \
# Exited Geography
# 0      France          4204        4204     4204         4204    4204  4204
#        Germany         1695        1695     1695         1695    1695  1695
#        Spain           2064        2064     2064         2064    2064  2064
# 1      France           810         810      810          810     810   810
#        Germany          814         814      814          814     814   814
#        Spain            413         413      413          413     413   413
#
#                   Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# Exited Geography
# 0      France       4204     4204           4204       4204            4204
#        Germany      1695     1695           1695       1695            1695
#        Spain        2064     2064           2064       2064            2064
# 1      France        810      810            810        810             810
# ...

# %%
data.groupby(['Exited','NumOfProducts']).count()
# Out:
#                       RowNumber  CustomerId  Surname  CreditScore  Geography  \
# Exited NumOfProducts
# 0      1                   3675        3675     3675         3675       3675
#        2                   4242        4242     4242         4242       4242
#        3                     46          46       46           46         46
# 1      1                   1409        1409     1409         1409       1409
#        2                    348         348      348          348        348
#        3                    220         220      220          220        220
#        4                     60          60       60           60         60
#
#                       Gender   Age  Tenure  Balance  HasCrCard  \
# Exited NumOfProducts
# 0      1                3675  3675    3675     3675       3675
#        2                4242  4242    4242     4242       4242
#        3                  46    46      46       46         46
# ...

# %%
data.groupby('Geography').count()
# Out:
#            RowNumber  CustomerId  Surname  CreditScore  Gender   Age  Tenure  \
# Geography
# France          5014        5014     5014         5014    5014  5014    5014
# Germany         2509        2509     2509         2509    2509  2509    2509
# Spain           2477        2477     2477         2477    2477  2477    2477
#
#            Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# Geography
# France        5014           5014       5014            5014             5014
# Germany       2509           2509       2509            2509             2509
# Spain         2477           2477       2477            2477             2477
#
#            Exited
# Geography
# France       5014
# Germany      2509
# Spain        2477

# %%
data.groupby(['Exited','Gender']).count()
# Out:
#                RowNumber  CustomerId  Surname  CreditScore  Geography   Age  \
# Exited Gender
# 0      Female       3404        3404     3404         3404       3404  3404
#        Male         4559        4559     4559         4559       4559  4559
# 1      Female       1139        1139     1139         1139       1139  1139
#        Male          898         898      898          898        898   898
#
#                Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# Exited Gender
# 0      Female    3404     3404           3404       3404            3404
#        Male      4559     4559           4559       4559            4559
# 1      Female    1139     1139           1139       1139            1139
#        Male       898      898            898        898             898
#
#                EstimatedSalary
# Exited Gender
# 0      Female             3404
#        Male               4559
# 1      Female             1139
#        Male                898

# %%
import matplotlib.pyplot as plt
plt.hist(data['CreditScore'])
# Out:
# (array([  19.,  166.,  447.,  958., 1444., 1866., 1952., 1525.,  968.,
#          655.]),
#  array([350., 400., 450., 500., 550., 600., 650., 700., 750., 800., 850.]),
#  <BarContainer object of 10 artists>)

# %%
import seaborn as sns
sns.boxplot(data['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
plt.bar(data['Geography'],data['CreditScore'])
# Out:
# <BarContainer object of 10000 artists>

# %%
plt.scatter(data['Age'],data['EstimatedSalary'])

# %%
plt.scatter(data['CreditScore'],data['Balance'])

# %%
data1=data.drop(['RowNumber','CustomerId','Surname'],axis=1)
data1
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France  Female   42       2       0.00              1
# 1             608     Spain  Female   41       1   83807.86              1
# 2             502    France  Female   42       8  159660.80              3
# 3             699    France  Female   39       1       0.00              2
# 4             850     Spain  Female   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France    Male   39       5       0.00              2
# 9996          516    France    Male   35      10   57369.61              1
# 9997          709    France  Female   36       7       0.00              1
# 9998          772   Germany    Male   42       3   75075.31              2
# 9999          792    France  Female   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
data1['Gender']=data1['Gender'].map({'Male':1,'Female':0})
data1
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       0   42       2       0.00              1
# 1             608     Spain       0   41       1   83807.86              1
# 2             502    France       0   42       8  159660.80              3
# 3             699    France       0   39       1       0.00              2
# 4             850     Spain       0   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       1   39       5       0.00              2
# 9996          516    France       1   35      10   57369.61              1
# 9997          709    France       0   36       7       0.00              1
# 9998          772   Germany       1   42       3   75075.31              2
# 9999          792    France       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
data1
# Out:
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             619    France       0   42       2       0.00              1
# 1             608     Spain       0   41       1   83807.86              1
# 2             502    France       0   42       8  159660.80              3
# 3             699    France       0   39       1       0.00              2
# 4             850     Spain       0   43       2  125510.82              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France       1   39       5       0.00              2
# 9996          516    France       1   35      10   57369.61              1
# 9997          709    France       0   36       7       0.00              1
# 9998          772   Germany       1   42       3   75075.31              2
# 9999          792    France       0   28       4  130142.79              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# ...

# %%
data2=pd.get_dummies(data1,dtype='int')
data2
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0             619       0   42       2       0.00              1          1
# 1             608       0   41       1   83807.86              1          0
# 2             502       0   42       8  159660.80              3          1
# 3             699       0   39       1       0.00              2          0
# 4             850       0   43       2  125510.82              1          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9995          771       1   39       5       0.00              2          1
# 9996          516       1   35      10   57369.61              1          1
# 9997          709       0   36       7       0.00              1          0
# 9998          772       1   42       3   75075.31              2          1
# 9999          792       0   28       4  130142.79              1          1
#
# ...

# %%
x=data2.drop(['Exited'],axis=1)
y=data2['Exited']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.33,random_state=0)

# %%
x_train
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 6596          477       1   22       5   82559.42              2          0
# 1292          794       0   41       7       0.00              2          1
# 2011          570       1   32       9  117337.54              2          0
# 4957          752       1   39       3       0.00              1          1
# 5164          642       1   36       4       0.00              2          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 9225          594       0   32       4  120074.97              2          1
# 4859          794       0   22       4  114440.24              1          1
# 3264          738       1   35       5  161274.05              2          1
# 9845          590       0   38       9       0.00              2          1
# 2732          623       0   48       1  108076.33              1          1
#
# ...

# %%
x_test
# Out:
#       CreditScore  Gender  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 9394          597       0   35       8  131101.04              1          1
# 898           523       0   40       2  102967.41              1          1
# 2398          706       0   42       8   95386.82              1          1
# 5906          788       1   32       4  112079.58              1          0
# 2343          706       1   38       5  163034.82              2          1
# ...           ...     ...  ...     ...        ...            ...        ...
# 4142          637       0   63       5       0.00              1          1
# 2067          744       1   31       9  120718.28              1          1
# 768           684       1   41       2  119782.72              2          0
# 5927          577       0   43       3  127940.47              1          0
# 2644          736       1   27       5   51522.75              1          0
#
# ...

# %%
from sklearn.linear_model import LogisticRegression
classifier=LogisticRegression()
classifier.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
ypred=classifier.predict(x_test)
ypred
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
y_test
# Out:
# 9394    0
# 898     1
# 2398    0
# 5906    0
# 2343    0
#        ..
# 4142    1
# 2067    0
# 768     0
# 5927    1
# 2644    0
# Name: Exited, Length: 3300, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,ypred)
# Out:
# 0.7815151515151515
